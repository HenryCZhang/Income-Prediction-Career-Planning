# %% [markdown]
# INF 2190 Assignment 2 Group 33

# %% [markdown]
# Income Rates, Career Satisfaction, and Career Choice Factors Among University Students

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Career_Path = pd.read_csv('Career_Path_Selection_Student_Responces.csv')

# %%
career_path_info = Career_Path.info()
print(career_path_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                    --------------  -----
#  0   Gender                                                                                                                                    101 non-null    object
#  1   Are you confident in your chosen career path?                                                                                             101 non-null    object
#  2   What factors affect your career decision-making process?                                                                                  101 non-null    object
# ...

# %% [markdown]
# **1) Are you confident in your chosen career path?**

# %%
# Count the responses for confidence in chosen career path
confidence_counts = Career_Path['Are you confident in your chosen career path?'].value_counts()


plt.figure(figsize=(8, 6))
Career_Path['Are you confident in your chosen career path?'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=['cornflowerblue', 'salmon'],
    textprops={'fontsize': 14}  # Setting font size for labels
)

plt.title('Proportion of Students Feeling Confident in Their Chosen Career Path', fontsize=16)
plt.ylabel('')  # Remove y-label for aesthetics
plt.show()

# %% [markdown]
# **2) What factors affect your career decision-making process?**

# %%
# Extract and clean the column for factors influencing career decisions
factors_column = Career_Path['What factors affect your career decision-making process?'].dropna()

# Split multiple selections and count occurrences of each factor
factor_counts = factors_column.str.get_dummies(sep=', ').sum()

plt.figure(figsize=(10, 8))
factor_counts.sort_values().plot(kind='barh', color='cornflowerblue')
plt.title("Factors Affecting Students' Career Decision-Making Process", fontsize=16)
plt.xlabel("Count of Students", fontsize=14)
plt.ylabel("Factors", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# The number one factor affecting students' career decision-making process is students' passion for a specific field. This is followed by financial stability and job market trends.

# %% [markdown]
# **3) How did you choose your career path?**

# %%
#Remove the extra space from the column name
Career_Path.columns = Career_Path.columns.str.strip()

# Extract and clean the column for factors influencing career path choices
factors_column = Career_Path['How_did you_choose_your_career_path?'].dropna()

# Split multiple selections and count occurrences of each factor
factor_counts = factors_column.str.get_dummies(sep=', ').sum()

plt.figure(figsize=(10, 8))
factor_counts.sort_values().plot(kind='barh', color='cornflowerblue')
plt.title("Impact of Factors on Students' Career Path Choices", fontsize=16)
plt.xlabel("Count of Students", fontsize=14)
plt.ylabel("Factors Influencing Career Path Choices", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# **4) Have you sought advice from a career counselor or career advisor?**

# %%
advice_counts = Career_Path['Have you sought advice from a career counselor or career advisor?'].value_counts()

plt.figure(figsize=(8, 6))
advice_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=['salmon','cornflowerblue'],  # "Yes" will be cornflowerblue, "No" will be salmon
    textprops={'fontsize': 14}  # Setting font size for labels
)

plt.title('Have you sought advice from a career counselor or career advisor?', fontsize=16)
plt.ylabel('')  # Remove y-label for aesthetics
plt.show()

# %% [markdown]
# Most students choose their career paths based on personal interests and passion. second major factor is the influence of their family and friends. A few students choose their career paths through professional counseling. (we can talk about why this is the case.)

# %% [markdown]
# **6) Do you think your current career choice aligns with your skills and strengths?**

# %%
alignment_counts = Career_Path['Do you think your current career choice aligns with your skills and strengths?'].value_counts()

plt.figure(figsize=(8, 6))
alignment_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=['cornflowerblue', 'salmon'],  # "Yes" will be cornflowerblue, "No" will be salmon
    textprops={'fontsize': 14}  # Setting font size for labels
)

plt.title('Do you think your current career choice aligns with your skills and strengths?', fontsize=16)
plt.ylabel('')  # Remove y-label for aesthetics
plt.show()

# %% [markdown]
# **7) Have you ever thought that the path you have chosen is not suitable for you? You could have done better if you had chosen another path.**

# %%
Career_Path.columns = Career_Path.columns.str.strip()

thought_counts = Career_Path['Have you ever thought that the path you have chosen is not suitable for you? You could have done better if you had chosen another path.'].value_counts()

plt.figure(figsize=(8, 6))
thought_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=['salmon', 'cornflowerblue',],  # "Yes" will be cornflowerblue, "No" will be salmon
    textprops={'fontsize': 14}  # Setting font size for labels
)

plt.title('Have you ever thought your chosen career path is unsuitable?', fontsize=16)
plt.ylabel('')  # Remove y-label for aesthetics
plt.show()

# %% [markdown]
# A notable 63% of students have not sought advice from a career counselor.

# %% [markdown]
# **8) If you realize that your initially chosen career path is not suitable for you, are you confident in shifting to a different career path?**

# %%
Career_Path.columns = Career_Path.columns.str.strip()

shift_confidence_counts = Career_Path['If you realize that your initially chosen career path is not suitable for you, are you confident in shifting to a different career path?'].value_counts()

plt.figure(figsize=(8, 6))
shift_confidence_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=['salmon', 'cornflowerblue',],
    textprops={'fontsize': 14}  # Setting font size for labels
)

plt.title('Confidence in Shifting to a Different Career Path', fontsize=16)
plt.ylabel('')  # Remove y-label for aesthetics
plt.show()

# %% [markdown]
# **10) Do you think schools/colleges should offer career counseling and guidance programs?**

# %%
Career_Path.columns = Career_Path.columns.str.strip()

counseling_counts = Career_Path['Do you think schools/colleges should offer career counseling and guidance programs?'].value_counts()

plt.figure(figsize=(8, 6))
counseling_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=['cornflowerblue', 'salmon'],  # Color assignment for 'Yes' and 'No'
    textprops={'fontsize': 14}  # Font size for labels
)

plt.title('Do you think schools/colleges should offer career counseling and guidance programs?', fontsize=16)
plt.ylabel('')  # Remove y-label for aesthetics
plt.show()

# %% [markdown]
# **11) In your opinion, what can educational institutions do to help students choose their career paths more effectively? (Open-ended)**

# %%
# Students' responses to what can educational institutions do to help students choose their career paths more effectively?
open_ended_responses = Career_Path["In your opinion, what can educational institutions do to help students choose their career paths more effectively? (Open-ended)"].dropna()

career_path_info, open_ended_responses.tolist()
# Out:
# (None,
#  ['Should have proper career counseling ',
#   'They open business not a training institute. ',
#   'Better career counseling and enhancing skills ',
#   'How to use the right skills to earn a living.',
#   'The Career Counseling Desk may not be the most effective method for guiding new students. Instead, I believe it would be more beneficial to employ multimedia support to present a comprehensive overview of various fields and their practical applications in the job market. Utilizing visual aids, we can demonstrate the professions associated with each study field, providing students with a clearer understanding of the career paths related to their chosen areas of study.',
#   "Educational institutes nees to provide career counseling to students because they don't know the scope of a specific field or they don't have enough knowledge about choosing the right career for them. ",
#   'They should arrange career counselling sessions more often ',
#   'Conducting seminars ',
# ...

# %% [markdown]
# Based on students' responses, many believe that educational institutions should prioritize career counseling and guidance programs to help students make informed decisions. Numerous students expressed that frequent counseling sessions are necessary to aid students in understanding diverse career options and aligning these choices with their interests and skills. There is also a call for career workshops, seminars, and interactions with professionals, allowing students to explore real-world applications of various fields. Additionally, some students highlighted the need for internship opportunities and hands-on activities to provide practical experiences. Many believe that early guidance, starting from high school, can better prepare students to choose a path that suits their aspirations and market demand, with teachers playing an essential role in nurturing students' career interests.
